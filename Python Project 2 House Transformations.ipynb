# %% [markdown]
# Name: ZHENG, Xi
# Student ID:50548249

# %% [markdown]
# ### Execute the cell below before proceeding.
#
# The code in this cell will need the file house_transformations.py. Make sure that you have download the file before executing it.

# %%
import requests
from house_transformations import *

# %% [markdown]
# # House Transformations
#
# The function `matrix_t()` shows the effect of a matrix transformation $T_A\colon {\mathbb R}^2 \to {\mathbb R}^2$ given by $T_A({\mathbf v}) = A{\mathbf v}$, where $A$ is a 2$\times$2 matrix.

# %% [markdown]
# Enter a 2$\times$2 matrix $E$:

# %%
E = Matrix([[1, 1], [3, 2]])
E
# Out:
# ⎡1  1⎤
# ⎢    ⎥
# ⎣3  2⎦

# %% [markdown]
# The next cell produces a picture demonstrating the effect of the linear transformation $T_A$. The image on the left shows a drawing of a house. The image of the right shows that same drawing after the transformation $T_A$ is applied to it. You can use controls above the picture to pan and zoom on it.

# %%
matrix_t(E)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="dcb7fff6-ca03-4993-a63d-195fbeb62655">Loading BokehJS ...</span>
#     </div>
#   <div id="fadcb8d5-27e7-4356-b32c-1b6be8ee6763" data-root-id="p1210" style="display: contents;"></div>

# %% [markdown]
# ## Exercises.
#
# In each exercises below, **FIND** a $2\times 2$ matrix $A$ such that the matrix transformation
# $$T_A \colon {\mathbb R}^2 \to  {\mathbb R}^2 $$
# transforms the image as indicated. **PLUG** $A$ into the function `matrix_t(A)` to recreate the picture accompanying the exercise.
#
# Note: The matrix $E$ above is just an example, you don't need to use that matrix for the exercise below at all!

# %% [markdown]
# ### Exercise 1.
#
# The transformation $T_A$ magnifies the image by the factor of 2:

# %%
# execute this cell to see the picture
show_pic("scale2")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/scale2.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Solution:

# %% [markdown]
# Find a 2 × 2 matrix  𝐴 :

# %%
A=Matrix([[2,0],[0,2]])
A
# Out:
# ⎡2  0⎤
# ⎢    ⎥
# ⎣0  2⎦

# %% [markdown]
# Check your answer by running the next line (The picture should be same!)

# %%
matrix_t(A)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cbc8ba7b-3746-46b9-99fa-e0c07be46e4f">Loading BokehJS ...</span>
#     </div>
#   <div id="c645e7af-de43-4205-b40d-dd96111f32b6" data-root-id="p1441" style="display: contents;"></div>

# %% [markdown]
# <br/>
# <hr>
#
# ### Exercise 2.
#
# The transformation $T_B$ reflect the image with respect to the $x$-axis:

# %%
# execute this cell to see the picture
show_pic("ref_x")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/ref_x.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Solution:

# %% [markdown]
# Find a 2 × 2 matrix  B :

# %%
B=Matrix([[1,0],[0,-1]])
B
# Out:
# ⎡1  0 ⎤
# ⎢     ⎥
# ⎣0  -1⎦

# %% [markdown]
# Check your answer by running the next line

# %%
matrix_t(B)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d50d0e99-d6b6-4c2a-8853-31a5773365c7">Loading BokehJS ...</span>
#     </div>
#   <div id="c8eee2a0-e44a-410b-976e-f01974961e3a" data-root-id="p1672" style="display: contents;"></div>

# %% [markdown]
# <br/>
# <hr>
#
# ### Exercise 3.
#
# The transformation $T_C$ reflect the image with respect to the $y$-axis:

# %%
# execute this cell to see the picture
show_pic("ref_y")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/ref_y.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Solution:

# %% [markdown]
# Enter a 2 × 2 matrix  C :

# %%
C=Matrix([[-1,0],[0,1]])
C
# Out:
# ⎡-1  0⎤
# ⎢     ⎥
# ⎣0   1⎦

# %% [markdown]
# Check your answer by running the next line

# %%
matrix_t(C)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ee43676c-2c2d-4dc9-8d3b-7cc163dfcbf0">Loading BokehJS ...</span>
#     </div>
#   <div id="ca50f0e8-d838-4758-b3c1-70af2ddc91af" data-root-id="p1903" style="display: contents;"></div>

# %% [markdown]
# <br/>
# <hr>
#
# ### Exercise 4.
#
# The transformation $T_D$ deforms the image as follows:

# %%
# execute this cell to see the picture
show_pic("skew1")
# Out:
#         <iframe
#             width="800"
#             height="410"
#             src="https://bbadzioch.github.io/MTH309_F2019/house_transformations_pics/skew1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Solution:

# %% [markdown]
# Enter a 2 × 2 matrix  D :

# %%
D=Matrix([[1,-2],[0,2]])
D
# Out:
# ⎡1  -2⎤
# ⎢     ⎥
# ⎣0  2 ⎦

# %% [markdown]
# Check your answer by running the next line

# %%
matrix_t(D)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ca674c1d-5a01-4cc2-872b-1c8a297cc8a3">Loading BokehJS ...</span>
#     </div>
#   <div id="a624a5e9-eb70-49ee-ad1a-727efd53b94c" data-root-id="p2134" style="display: contents;"></div>

# %% [markdown]
# <br/>
# <hr>
#
#
# ### Exercise 5.
#
# Lets try composing some of these transformation from previous exercises and see what's going on.
# Here is $T_B \circ T_C=T_{BC}$.

# %%
# execute this cell to see the picture
matrix_t(B*C)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fcad180d-cb33-4efc-ac06-426c8959b35d">Loading BokehJS ...</span>
#     </div>
#   <div id="a4f4634d-d7f7-4702-a40c-c345e050e482" data-root-id="p2365" style="display: contents;"></div>

# %% [markdown]
# Here is $T_C \circ T_B=T_{CB}$.

# %%
# execute this cell to see the picture
matrix_t(C*B)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ca336d24-fc86-4bb4-8fd1-c6a4fbd577b4">Loading BokehJS ...</span>
#     </div>
#   <div id="cd036f1b-e242-4ead-8a46-c9b21f9794be" data-root-id="p2596" style="display: contents;"></div>

# %% [markdown]
# Question: Are $T_{BC}$ and $T_{CB}$ the same transform?

# %% [markdown]
# Answer: Yes

# %% [markdown]
# Here is why. Compute these two products of matrices. Hint: Use some command from Linear algebra with Python and SymPy (part 3), i.e. the file linalg_sympy3
# in Python resourses on UBLearns

# %% [markdown]
# Compute the product BC:

# %%
B*C
# Out:
# ⎡-1  0 ⎤
# ⎢      ⎥
# ⎣0   -1⎦

# %% [markdown]
# Compute the product CB:

# %%
C*B
# Out:
# ⎡-1  0 ⎤
# ⎢      ⎥
# ⎣0   -1⎦
